# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_excel(r'C:\Users\hp\OneDrive\Masaüstü\kanada verisi.xlsx')

# %%
data.head()
# Out:
#       City      Price                  Address  Number_Beds  Number_Baths  \
# 0  Toronto   779900.0    #318 -20 SOUTHPORT ST            3             2
# 1  Toronto   799999.0    #818 -60 SOUTHPORT ST            3             1
# 2  Toronto   799900.0  #714 -859 THE QUEENSWAY            2             2
# 3  Toronto  1200000.0         275 MORTIMER AVE            4             2
# 4  Toronto   668800.0    #420 -388 RICHMOND ST            1             1
#
#   Province  Population  Latitude  Longitude  Median_Family_Income
# 0  Ontario     5647656   43.7417   -79.3733                 97000
# 1  Ontario     5647656   43.7417   -79.3733                 97000
# 2  Ontario     5647656   43.7417   -79.3733                 97000
# 3  Ontario     5647656   43.7417   -79.3733                 97000
# 4  Ontario     5647656   43.7417   -79.3733                 97000

# %%
data_df = pd.DataFrame(data)

# %% [markdown]
# # HİSTOGRAM GRAFİKLERİ

# %%
plt.hist(data_df['Price'],bins=50, edgecolor='black')
plt.grid(True)
plt.show()

# %%
plt.hist(data_df['Population'],bins=20, edgecolor='black')
plt.grid(True)
plt.show()

# %%
plt.hist(data_df['Median_Family_Income'],bins=25, edgecolor='black')
plt.grid(True)
plt.show()

# %%
plt.hist(data_df['Number_Beds'],bins=60, edgecolor='black')
plt.grid(True)
plt.show()

# %%
data_df['City'].value_counts().plot(kind='bar')
plt.grid(True)
plt.show()

# %%
data_df['Province'].value_counts().plot(kind='bar')
plt.grid(True)
plt.show()

# %% [markdown]
# # NORMALLİK TESTİ

# %%
from scipy import stats

# %%
shapiro_test = stats.shapiro(data_df['Median_Family_Income'])
shapiro_test.pvalue
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\scipy\stats\_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# 0.0

# %%
shapiro_test = stats.shapiro(data_df['Price'])
shapiro_test.pvalue
# Out:
# 0.0

# %% [markdown]
# # BOXPLOT GRAFİKLERİ

# %%
plt.boxplot(data_df['Number_Baths'])
plt.title('Number Baths Box-plot Grafiği')
plt.xlabel('Veriler')
plt.ylabel('Frekans')
plt.show()

# %%
plt.boxplot(data_df['Median_Family_Income'])
plt.title('Median Family Income Box-plot Grafiği')
plt.xlabel('Veriler')
plt.ylabel('Frekans')
plt.show()

# %%
plt.boxplot(data_df['Number_Beds'])
plt.title('Nmuber Beds Box-plot Grafiği')
plt.xlabel('Veriler')
plt.ylabel('Frekans')
plt.show()

# %%
plt.boxplot(data_df['Price'])
plt.title('Price Box-plot Grafiği')
plt.xlabel('Veriler')
plt.ylabel('Frekans')
plt.show()

# %%
plt.boxplot(data_df['Population'])
plt.title('Population Box-plot Grafiği')
plt.xlabel('Veriler')
plt.ylabel('Frekans')
plt.show()

# %% [markdown]
# # OUTLİER İNCELEMESİ

# %%
print(data_df.isnull().sum())
# Out:
# City                    0
# Price                   0
# Address                 0
# Number_Beds             0
# Number_Baths            0
# Province                0
# Population              0
# Latitude                0
# Longitude               0
# Median_Family_Income    0
# dtype: int64

# %%
Q1 = data_df['Number_Beds'].quantile(0.25)
Q3 = data_df['Number_Beds'].quantile(0.75)
IQR = Q3 - Q1

# %%
alt_sinir = Q1 - 1.5*IQR
ust_sinir = Q3 + 1.5*IQR
print(alt_sinir)
print(ust_sinir)
# Out:
# -1.0
# 7.0

# %%
clean_data1 = data_df[(data_df['Number_Beds'] >= alt_sinir) & (data_df['Number_Beds'] <= ust_sinir)]
print(clean_data1)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
Q1 = data_df['Number_Baths'].quantile(0.25)
Q3 = data_df['Number_Baths'].quantile(0.75)
IQR = Q3 - Q1

# %%
alt_sinir = Q1 - 1.5*IQR
ust_sinir = Q3 + 1.5*IQR
print(alt_sinir)
print(ust_sinir)
# Out:
# 0.5
# 4.5

# %%
clean_data2 = clean_data1[(clean_data1['Number_Baths'] >= alt_sinir) & (clean_data1['Number_Baths'] <= ust_sinir)]
print(clean_data2)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
Q1 = data_df['Price'].quantile(0.25)
Q3 = data_df['Price'].quantile(0.75)
IQR = Q3 - Q1
alt_sinir = Q1 - 1.5*IQR
ust_sinir = Q3 + 1.5*IQR
print(alt_sinir)
print(ust_sinir)
# Out:
# -492750.0
# 2047650.0

# %%
clean_data3 = clean_data2[(clean_data2['Price'] >= alt_sinir) & (clean_data2['Price'] <= ust_sinir)]
print(clean_data3)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # z score normalization

# %%
from sklearn import preprocessing

# %%
price_df = data_df['Price'].astype(float)

# %%
price_reshape = price_df.array.reshape(-1,1)

# %%
print(preprocessing.normalize(price_reshape))
# Out:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
print(preprocessing.scale(price_reshape))
# Out:
# [[-0.16017731]
#  [-0.14047427]
#  [-0.14057132]
#  ...
#  [-0.51308524]
#  [ 0.00647365]
#  [-0.34349337]]
